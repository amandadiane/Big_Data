# %% [markdown]
# # Speed Dating Match Predictions
# Using the https://www.kaggle.com/annavictoria/speed-dating-experiment data set.

# %%
import keras
from keras import optimizers
from keras import losses
from keras import metrics
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from keras.preprocessing import sequence

from sklearn import metrics
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from IPython.display import Image
import pydotplus

import numpy as np
from numpy import argmax

import matplotlib.pyplot as plt

# %%
# loading the data
import pandas as pd
data = pd.read_csv('./data/SpeedDatingData.csv', engine='python')

# %%
# remove features that will not impact the match
data = data.drop(columns=['iid', 'pid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position', 'positin1',
                         'partner', ])
# remove features with not enough data
data = data.drop(columns=[i for i in data.columns if (data[i].count() < 6000)])

# %%
# drop rows with no data in 'match' column
data['match'] = pd.to_numeric(data['match'], errors='coerce')
data = data.dropna()

# display values in each class
target_count = data.match.value_counts()
target_count.plot(kind='bar', title='Target Counts')

# set aside labels as target vector
labels = list(data['match'])
labels = [int(i) for i in labels]
data = data.drop(columns=['match'])

# remove categorical features
cat_cols = [i for i in data.columns if data[i].dtype != 'float']
data = data.drop(columns=[i for i in cat_cols])

# %%
# oversampling data to improve class balance
from imblearn.over_sampling import SMOTE
data_resampled, labels_resampled = SMOTE().fit_resample(data, labels)

# %%
print(data_resampled.shape)
print(labels_resampled.shape)
# Out:
# (4580, 92)
# (4580,)

# %%
# split the data into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data_resampled, labels_resampled, test_size=0.30)

# %%
from keras.utils import to_categorical
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3206, 92)
# (1374, 92)
# (3206, 2)
# (1374, 2)

# %%
# create validation set
val_size = int(np.round(len(x_train)*.2))
x_val = x_train[:val_size]
x_train_minus_val = x_train[val_size:]

y_val = y_train[:val_size]
y_train_minus_val = y_train[val_size:]

# %%
x_val.shape
# Out:
# (641, 92)

# %%
# train basic RNN
rnn_model = Sequential()
rnn_model.add(Dense(128, activation='relu', input_shape=(92,)))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dropout(.1))
rnn_model.add(Dense(2, activation='softmax')) 

rnn_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

rnn_history = rnn_model.fit(x_train_minus_val,
                    y_train_minus_val,
                    epochs=20,
                    batch_size=216,
                    validation_data=(x_val, y_val))
# Out:
# Train on 2565 samples, validate on 641 samples
# Epoch 1/20
# 2565/2565 [==============================] - 1s 374us/step - loss: 1.3299 - acc: 0.5084 - val_loss: 0.7585 - val_acc: 0.5242
# Epoch 2/20
# 2565/2565 [==============================] - 0s 21us/step - loss: 0.7174 - acc: 0.5669 - val_loss: 0.6379 - val_acc: 0.6443
# Epoch 3/20
# 2565/2565 [==============================] - 0s 21us/step - loss: 0.6395 - acc: 0.6347 - val_loss: 0.5881 - val_acc: 0.6849
# Epoch 4/20
# 2565/2565 [==============================] - 0s 21us/step - loss: 0.5746 - acc: 0.6990 - val_loss: 0.5362 - val_acc: 0.7504
# Epoch 5/20
# 2565/2565 [==============================] - 0s 21us/step - loss: 0.5285 - acc: 0.7450 - val_loss: 0.4882 - val_acc: 0.7956
# Epoch 6/20
# 2565/2565 [==============================] - 0s 21us/step - loss: 0.4891 - acc: 0.7559 - val_loss: 0.4563 - val_acc: 0.7988
# Epoch 7/20
# ...

# %%
# accuracy and loss

loss = rnn_history.history['loss']
val_loss = rnn_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()
acc = rnn_history.history['acc']
val_acc = rnn_history.history['val_acc']
plt.plot(epochs, acc, 'go', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Initial RNN achieves about 85% accuracy on the validation set. I used a large network, and I hypothesize that this increased performance because there were so many features in the dataset (92).
#
# Given that I only did some basic data cleaning, I'm going to spend more time on that piece and see if I can bring my results up even further.

# %%
# decision tree and random forest classifiers for comparison
dt_model = DecisionTreeClassifier()
dt_model = dt_model.fit(x_train, y_train)
y_pred = dt_model.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.8682678311499272

# %%
dot_data = StringIO()
export_graphviz(dt_model, out_file=dot_data,
               filled=True,
               special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('speed_dating_tree.png')
Image(graph.create_png())

# %%
dt_model2 = DecisionTreeClassifier(criterion='entropy', max_depth=10)
dt_model2 = dt_model2.fit(x_train, y_train)
y_pred = dt_model2.predict(x_test)

print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.8617176128093159

# %% [markdown]
# ## More Data Cleaning

# %%
# one hot encode certain values which are coded numerically, giving an unintended rank to the responses
cols_to_ohe = ['race_o', 'race', 'field_cd', 'goal', 'career_c']
for col in cols_to_ohe:
    data = pd.concat([data, pd.get_dummies(data[col], prefix=col)], axis=1)
    data.drop([col], axis=1, inplace=True)

# %%
# scale the data to avoid certain values like income dominating the model
from sklearn import preprocessing

scaler = preprocessing.StandardScaler()
scaled = scaler.fit_transform(data)
scaled_data = pd.DataFrame(scaled, columns=data.columns)

# %%
# processing data again into balanced set
data_resampled, labels_resampled = SMOTE().fit_resample(scaled_data, labels)

# %%
print(data_resampled.shape)
print(labels_resampled.shape)
# Out:
# (4580, 133)
# (4580,)

# %%
x_train, x_test, y_train, y_test = train_test_split(data_resampled, labels_resampled, test_size=0.30)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# create validation set
val_size = int(np.round(len(x_train)*.2))
x_val = x_train[:val_size]
x_train_minus_val = x_train[val_size:]

y_val = y_train[:val_size]
y_train_minus_val = y_train[val_size:]

# %%
x_val.shape
# Out:
# (641, 133)

# %%
# trying basic RNN with these updates made
# train basic RNN with additional epochs
rnn_model = Sequential()
rnn_model.add(Dense(128, activation='relu', input_shape=(133,)))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dense(64, activation='relu'))
rnn_model.add(Dropout(.1))
rnn_model.add(Dense(2, activation='sigmoid')) 

rnn_model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

rnn_history = rnn_model.fit(x_train_minus_val,
                    y_train_minus_val,
                    epochs=30,
                    batch_size=216,
                    validation_data=(x_val, y_val))
# Out:
# Train on 2565 samples, validate on 641 samples
# Epoch 1/30
# 2565/2565 [==============================] - 1s 358us/step - loss: 0.6613 - acc: 0.6135 - val_loss: 0.5991 - val_acc: 0.7340
# Epoch 2/30
# 2565/2565 [==============================] - 0s 18us/step - loss: 0.5088 - acc: 0.7953 - val_loss: 0.4687 - val_acc: 0.7785
# Epoch 3/30
# 2565/2565 [==============================] - 0s 19us/step - loss: 0.3846 - acc: 0.8425 - val_loss: 0.4257 - val_acc: 0.8144
# Epoch 4/30
# 2565/2565 [==============================] - 0s 17us/step - loss: 0.3090 - acc: 0.8791 - val_loss: 0.3975 - val_acc: 0.8393
# Epoch 5/30
# 2565/2565 [==============================] - 0s 17us/step - loss: 0.2579 - acc: 0.9055 - val_loss: 0.3898 - val_acc: 0.8456
# Epoch 6/30
# 2565/2565 [==============================] - 0s 16us/step - loss: 0.2107 - acc: 0.9250 - val_loss: 0.3748 - val_acc: 0.8580
# Epoch 7/30
# ...

# %%
# accuracy and loss

loss = rnn_history.history['loss']
val_loss = rnn_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()
acc = rnn_history.history['acc']
val_acc = rnn_history.history['val_acc']
plt.plot(epochs, acc, 'go', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# Interestingly, overfitting happens much more quickly in this version, but I'm getting about 4 points increase in validation accuracy with the scaled and one-hot-encoded data, which is cool!
#
# It's possible that this model, now that the data is in a much cleaner state, is too complicated for the task. I'll experiment with fewer neurons, fewer layers, and different types of layers next.

# %%
x_train, x_test, y_train, y_test = train_test_split(data_resampled, labels_resampled, test_size=0.30)

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
# reshaping data into 3d format
x_train = x_train.reshape(3206, 1, 133)
x_test = x_test.reshape(1374, 1, 133)

# %%
print(x_test.shape)
# Out:
# (1374, 1, 133)

# %%
# create validation set
val_size = int(np.round(len(x_train)*.2))
x_val = x_train[:val_size]
x_train_minus_val = x_train[val_size:]

y_val = y_train[:val_size]
y_train_minus_val = y_train[val_size:]

# %%
print(x_val.shape)
# Out:
# (641, 1, 133)

# %%
# playing with SimpleRNNs
from keras.layers import SimpleRNN
from keras.layers import Reshape
from keras import backend as K
K.clear_session()

model_2 = Sequential()
model_2.add(SimpleRNN(128, input_shape=(1,133,), return_sequences=True))
model_2.add(SimpleRNN(64, return_sequences=True))
model_2.add(Dropout(.1))
model_2.add(SimpleRNN(32))
model_2.add(Dropout(.1))
model_2.add(Dense(2, activation='sigmoid')) 

model_2.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1 (SimpleRNN)     (None, 1, 128)            33536
# _________________________________________________________________
# simple_rnn_2 (SimpleRNN)     (None, 1, 64)             12352
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 64)             0
# _________________________________________________________________
# simple_rnn_3 (SimpleRNN)     (None, 32)                3104
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# ...
# Total params: 49,058
# Trainable params: 49,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model_2.fit(x_train_minus_val,
                    y_train_minus_val,
                    epochs=30,
                    batch_size=128,
                    validation_data=(x_val, y_val))

# accuracy and loss

loss = rnn_history.history['loss']
val_loss = rnn_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()
acc = rnn_history.history['acc']
val_acc = rnn_history.history['val_acc']
plt.plot(epochs, acc, 'go', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train on 2565 samples, validate on 641 samples
# Epoch 1/30
# 2565/2565 [==============================] - 1s 383us/step - loss: 0.5931 - acc: 0.6809 - val_loss: 0.5092 - val_acc: 0.7590
# Epoch 2/30
# 2565/2565 [==============================] - 0s 33us/step - loss: 0.4556 - acc: 0.7975 - val_loss: 0.4754 - val_acc: 0.7855
# Epoch 3/30
# 2565/2565 [==============================] - 0s 38us/step - loss: 0.3976 - acc: 0.8357 - val_loss: 0.4407 - val_acc: 0.8089
# Epoch 4/30
# 2565/2565 [==============================] - 0s 37us/step - loss: 0.3551 - acc: 0.8595 - val_loss: 0.4225 - val_acc: 0.8222
# Epoch 5/30
# 2565/2565 [==============================] - 0s 38us/step - loss: 0.3226 - acc: 0.8825 - val_loss: 0.4180 - val_acc: 0.8409
# Epoch 6/30
# 2565/2565 [==============================] - 0s 36us/step - loss: 0.2977 - acc: 0.8916 - val_loss: 0.3935 - val_acc: 0.8479
# Epoch 7/30
# ...

# %%
# playing with LSTMs
from keras.layers import LSTM
from keras.layers import Reshape
from keras import backend as K
K.clear_session()

model_3 = Sequential()
model_3.add(LSTM(64, input_shape=(1,133,), return_sequences=True))
model_3.add(LSTM(64, return_sequences=True))
model_3.add(Dropout(.1))
model_3.add(LSTM(64))
model_3.add(Dropout(.1))
model_3.add(Dense(2, activation='sigmoid'))

model_3.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 1, 64)             50688
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 1, 64)             33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 64)             0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 64)                33024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# ...
# Total params: 116,866
# Trainable params: 116,866
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_3.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model_3.fit(x_train_minus_val,
                    y_train_minus_val,
                    epochs=30,
                    batch_size=128,
                    validation_data=(x_val, y_val))

# accuracy and loss

loss = rnn_history.history['loss']
val_loss = rnn_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'go', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

plt.clf()
acc = rnn_history.history['acc']
val_acc = rnn_history.history['val_acc']
plt.plot(epochs, acc, 'go', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Train on 2565 samples, validate on 641 samples
# Epoch 1/30
# 2565/2565 [==============================] - 2s 895us/step - loss: 0.6884 - acc: 0.6657 - val_loss: 0.6769 - val_acc: 0.7262
# Epoch 2/30
# 2565/2565 [==============================] - 0s 53us/step - loss: 0.6414 - acc: 0.7653 - val_loss: 0.5783 - val_acc: 0.7722
# Epoch 3/30
# 2565/2565 [==============================] - 0s 50us/step - loss: 0.5051 - acc: 0.8029 - val_loss: 0.4926 - val_acc: 0.8058
# Epoch 4/30
# 2565/2565 [==============================] - 0s 50us/step - loss: 0.4118 - acc: 0.8507 - val_loss: 0.4327 - val_acc: 0.8268
# Epoch 5/30
# 2565/2565 [==============================] - 0s 48us/step - loss: 0.3350 - acc: 0.8817 - val_loss: 0.3892 - val_acc: 0.8424
# Epoch 6/30
# 2565/2565 [==============================] - 0s 46us/step - loss: 0.2802 - acc: 0.9043 - val_loss: 0.3668 - val_acc: 0.8526
# Epoch 7/30
# ...

# %%
# playing with LSTMs
from keras.layers import LSTM
from keras.layers import Reshape
from keras import backend as K
K.clear_session()

model_3 = Sequential()
model_3.add(SimpleRNN(128, input_shape=(1,133,), return_sequences=True))
model_3.add(LSTM(64, return_sequences=True))
model_3.add(Dropout(.1))
model_3.add(LSTM(32))
model_3.add(Dropout(.1))
model_3.add(Dense(2, activation='sigmoid'))

model_3.summary()
