# %% [markdown]
# Amanda Baker, andrewID: adbaker

# %% [markdown]
# ### Part 5: Analyze the Data
# #### i. Clean the data

# %%
import pandas as pd
import numpy as np

appstore_apps = pd.read_csv('a3-adbaker-itunes-topapps-2.csv')

def convert_tick_values(v):
    'Accepts a number v expressed in tick value (e.g. 1M, 2.5K), and returns its numeric value.'
    if (v[-1] == 'K'):
        full_value = float(v[:-1]) * 1000
    elif (v[-1] == 'M'):
        full_value = float(v[:-1]) * 1000000
    elif (v[-1] == 'B'):
        full_value = float(v[:-1]) * 1000000000
    else:
        full_value = v
    return int(full_value)

appstore_apps['star_rating'] = appstore_apps['star_rating'].apply(lambda s: float(s))
appstore_apps['count_ratings'] = appstore_apps['count_ratings'].apply(lambda s: s[:-8].strip())
appstore_apps['count_ratings'] = appstore_apps['count_ratings'].apply(lambda s: convert_tick_values(s))

appstore_apps.head()
# Out:
#                    app_name       category  \
# 0                    PLANK!          Games
# 1         Perfect Hit . . .          Games
# 2             Google Photos  Photo & Video
# 3                  Cash App        Finance
# 4  Wish - Shopping Made Fun       Shopping
#
#                                    appstore_link_url  \
# 0  https://itunes.apple.com/us/app/plank/id137048...
# 1  https://itunes.apple.com/us/app/perfect-hit/id...
# 2  https://itunes.apple.com/us/app/google-photos/...
# 3  https://itunes.apple.com/us/app/cash-app/id711...
# 4  https://itunes.apple.com/us/app/wish-shopping-...
#
#                                          img_src_url  star_rating  \
# 0  https://www.apple.com/autopush/us/itunes/chart...          4.5
# 1  https://www.apple.com/autopush/us/itunes/chart...          4.5
# 2  https://www.apple.com/autopush/us/itunes/chart...          4.7
# 3  https://www.apple.com/autopush/us/itunes/chart...          4.6
# 4  https://www.apple.com/autopush/us/itunes/chart...          4.6
#
#    count_ratings
# 0          93700
# 1          53600
# 2         136000
# 3         150400
# 4         612400

# %% [markdown]
# #### ii. List the names of the top apps sorted in descending order based on star rating and within those with the same star rating sort based on number of ratings. If the number of ratings are also the same, sort by app_name.

# %%
appstore_apps_sorted = appstore_apps.sort_values(by=['star_rating', 'count_ratings', 'app_name'], ascending=[False, False, True])
appstore_apps_sorted.head(10)
# Out:
#                        app_name       category  \
# 73  Venmo: Send & Receive Money        Finance
# 80                         Lyft         Travel
# 28                       Shazam          Music
# 64                        Bible      Reference
# 63          PayPal: Mobile Cash        Finance
# 27     Lime - Your Ride Anytime         Travel
# 37        Bird - Enjoy The Ride         Travel
# 23                         Nike       Shopping
# 52                   Wordscapes          Games
# 97                    Instagram  Photo & Video
#
#                                     appstore_link_url  \
# 73  https://itunes.apple.com/us/app/venmo-send-rec...
# 80  https://itunes.apple.com/us/app/lyft/id5293790...
# 28  https://itunes.apple.com/us/app/shazam/id28499...
# 64  https://itunes.apple.com/us/app/bible/id282935...
# 63  https://itunes.apple.com/us/app/paypal-mobile-...
# 27  https://itunes.apple.com/us/app/lime-your-ride...
# 37  https://itunes.apple.com/us/app/bird-enjoy-the...
# 23  https://itunes.apple.com/us/app/nike/id1095459...
# 52  https://itunes.apple.com/us/app/wordscapes/id1...
# 97  https://itunes.apple.com/us/app/instagram/id38...
#
#                                           img_src_url  star_rating  \
# 73  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 80  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 28  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 64  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 63  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 27  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 37  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 23  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 52  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 97  https://www.apple.com/autopush/us/itunes/chart...          4.8
#
#     count_ratings
# 73        4800000
# 80        3800000
# 28        2800000
# 64        2700000
# 63        1400000
# 27         673200
# 37         408300
# 23         384200
# 52         276300
# 97        9500000

# %% [markdown]
# #### iii. For each category list the number of apps.

# %%
app_cat_pvt = appstore_apps_sorted.pivot_table(index='category', values='app_name', aggfunc=np.count_nonzero)
app_cat_pvt.columns=['apps_per_category']
app_cat_pvt.sort_values(by='apps_per_category', ascending=False)
# Out:
#                    apps_per_category
# category
# Games                             45
# Shopping                          10
# Social Networking                  7
# Food & Drink                       5
# Music                              5
# Travel                             5
# Entertainment                      4
# Photo & Video                      4
# Finance                            3
# Productivity                       3
# Lifestyle                          2
# Navigation                         2
# Reference                          2
# Utilities                          2
# Education                          1

# %% [markdown]
# #### iv. For each category of app, list the average rating of all apps in that category and sort in descending order by average rating.

# %%
# code written if the user wanted to display the count of apps and the avg. star rating together
'''app_rating_pvt = appstore_apps_sorted.pivot_table(index='category', values=['app_name', 'star_rating'], aggfunc=[np.count_nonzero, np.mean])
app_rating_pvt.columns = ['apps_per_category','star_rating_counts', 'avg_star_rating']
app_rating_pvt = app_rating_pvt.drop(labels='star_rating_counts', axis=1).sort_values(by='avg_star_rating', ascending=False)
app_rating_pvt'''

# submitted answer
app_rating_pvt = appstore_apps_sorted.pivot_table(index='category', values='star_rating', aggfunc=np.mean)
app_rating_pvt.columns = ['avg_star_rating']
app_rating_pvt.sort_values(by='avg_star_rating', ascending=False)
# Out:
#                    avg_star_rating
# category
# Education                 4.800000
# Finance                   4.800000
# Travel                    4.760000
# Food & Drink              4.760000
# Music                     4.760000
# Navigation                4.750000
# Reference                 4.700000
# Productivity              4.666667
# Lifestyle                 4.600000
# Shopping                  4.570000
# Games                     4.548889
# Utilities                 4.500000
# Social Networking         4.442857
# Entertainment             4.400000
# Photo & Video             4.150000

# %% [markdown]
# #### v. For each category, list the app with the highest star rating. If there is a tie for apps with the highest star rating, list the one with the most number of ratings.

# %%
cat_grps_max_rating = appstore_apps.groupby('category')
highest_rated_in_grp = [cat_grps_max_rating.get_group(key).nlargest(1, ['star_rating', 'count_ratings']) 
                        for key in cat_grps_max_rating.groups.keys()]

# concatenate each dataframe containing highest rated app into single dataframe, and name columns appropriately
highest_rated_by_cat = pd.concat(highest_rated_in_grp[df] for df in np.arange(0,15))
highest_rated_by_cat.columns = ['highest_rated_app', 'category', 'appstore_link_url', 
                                'img_src_url', 'star_rating', 'count_ratings']
highest_rated_by_cat
# Out:
#                  highest_rated_app           category  \
# 72    Remind: School Communication          Education
# 47              Amazon Prime Video      Entertainment
# 73     Venmo: Send & Receive Money            Finance
# 24                       Starbucks       Food & Drink
# 52                      Wordscapes              Games
# 29  Zillow: Houses For Sale & Rent          Lifestyle
# 28                          Shazam              Music
# 5   Waze Navigation & Live Traffic         Navigation
# 97                       Instagram      Photo & Video
# 53                    Google Drive       Productivity
# 64                           Bible          Reference
# 23                            Nike           Shopping
# 79                       Pinterest  Social Networking
# 80                            Lyft             Travel
# 56       Emoji Me Keyboard | Zmoji          Utilities
#
#                                     appstore_link_url  \
# 72  https://itunes.apple.com/us/app/remind-school-...
# 47  https://itunes.apple.com/us/app/amazon-prime-v...
# 73  https://itunes.apple.com/us/app/venmo-send-rec...
# 24  https://itunes.apple.com/us/app/starbucks/id33...
# 52  https://itunes.apple.com/us/app/wordscapes/id1...
# 29  https://itunes.apple.com/us/app/zillow-houses-...
# 28  https://itunes.apple.com/us/app/shazam/id28499...
# 5   https://itunes.apple.com/us/app/waze-navigatio...
# 97  https://itunes.apple.com/us/app/instagram/id38...
# 53  https://itunes.apple.com/us/app/google-drive/i...
# 64  https://itunes.apple.com/us/app/bible/id282935...
# 23  https://itunes.apple.com/us/app/nike/id1095459...
# 79  https://itunes.apple.com/us/app/pinterest/id42...
# 80  https://itunes.apple.com/us/app/lyft/id5293790...
# 56  https://itunes.apple.com/us/app/emoji-me-keybo...
#
#                                           img_src_url  star_rating  \
# 72  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 47  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 73  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 24  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 52  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 29  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 28  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 5   https://www.apple.com/autopush/us/itunes/chart...          4.8
# 97  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 53  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 64  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 23  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 79  https://www.apple.com/autopush/us/itunes/chart...          4.8
# 80  https://www.apple.com/autopush/us/itunes/chart...          4.9
# 56  https://www.apple.com/autopush/us/itunes/chart...          4.8
#
#     count_ratings
# 72         222100
# 47         925300
# 73        4800000
# 24        2700000
# 52         276300
# 29        2700000
# 28        2800000
# 5         1500000
# 97        9500000
# 53        2100000
# 64        2700000
# 23         384200
# 79        2300000
# 80        3800000
# 56          70700
